# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# Import BaggingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
ilp = pd.read_csv("indian_liver_patient_preprocessed.csv")
X = ilp.drop(['Liver_disease'], axis=1)
y = ilp['Liver_disease']
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, stratify=y, random_state=1)

# %%
# Instantiate dt
dt = DecisionTreeClassifier(random_state=1)

# Instantiate bc
bc = BaggingClassifier(base_estimator=dt, n_estimators=50, random_state=1)

# %%
# Fit bc to the training set
bc.fit(X_train, y_train)

# Predict test set labels
y_pred = bc.predict(X_test)

# Evaluate acc_test
acc_test = accuracy_score(y_test, y_pred)
print('Test set accuracy of bc: {:.2f}'.format(acc_test))
# Out:
# Test set accuracy of bc: 0.71

# %%
# Instantiate dt
dt = DecisionTreeClassifier(min_samples_leaf=8, random_state=1)

# Instantiate bc
bc = BaggingClassifier(base_estimator=dt, 
            n_estimators=50,
            oob_score=True,
            random_state=1)

# %%
# Fit bc to the training set 
bc.fit(X_train, y_train)

# Predict test set labels
y_pred = bc.predict(X_test)

# Evaluate test set accuracy
acc_test = accuracy_score(y_test, y_pred)

# Evaluate OOB accuracy
acc_oob = bc.oob_score_

# Print acc_test and acc_oob
print('Test set accuracy: {:.3f}, OOB accuracy: {:.3f}'.format(acc_test, acc_oob))
# Out:
# Test set accuracy: 0.690, OOB accuracy: 0.708

# %%
bike = pd.read_csv('bikes.csv')
bike
# Out:
#       hr  holiday  workingday  temp   hum  windspeed  cnt  instant  mnth  yr  \
# 0      0        0           0  0.76  0.66     0.0000  149    13004     7   1
# 1      1        0           0  0.74  0.70     0.1343   93    13005     7   1
# 2      2        0           0  0.72  0.74     0.0896   90    13006     7   1
# 3      3        0           0  0.72  0.84     0.1343   33    13007     7   1
# 4      4        0           0  0.70  0.79     0.1940    4    13008     7   1
# 5      5        0           0  0.68  0.79     0.1045   10    13009     7   1
# 6      6        0           0  0.70  0.79     0.0896   27    13010     7   1
# 7      7        0           0  0.74  0.70     0.0000   50    13011     7   1
# 8      8        0           0  0.78  0.62     0.1045  142    13012     7   1
# 9      9        0           0  0.82  0.56     0.0000  219    13013     7   1
# 10    10        0           0  0.86  0.44     0.2985  366    13014     7   1
# 11    11        0           0  0.88  0.39     0.2239  377    13015     7   1
# 12    12        0           0  0.90  0.37     0.2239  433    13016     7   1
# 13    13        0           0  0.92  0.33     0.2537  420    13017     7   1
# 14    14        0           0  0.92  0.33     0.2537  444    13018     7   1
# 15    15        0           0  0.90  0.37     0.2836  345    13019     7   1
# 16    16        0           0  0.92  0.33     0.2985  313    13020     7   1
# 17    17        0           0  0.92  0.26     0.2985  413    13021     7   1
# 18    18        0           0  0.88  0.32     0.3582  370    13022     7   1
# 19    19        0           0  0.84  0.39     0.1343  382    13023     7   1
# 3                          1                    0      0
# 4                          1                    0      0
# 5                          1                    0      0
# 6                          1                    0      0
# 7                          1                    0      0
# 8                          1                    0      0
# 9                          1                    0      0
# 10                         1                    0      0
# 11                         1                    0      0
# 12                         1                    0      0
# 13                         1                    0      0
# 14                         1                    0      0
# 15                         1                    0      0
# 16                         1                    0      0
# 17                         1                    0      0
# 18                         1                    0      0
# 19                         1                    0      0
# 20                         1                    0      0
# 21                         1                    0      0
# 22                         1                    0      0
# 23                         0                    1      0
# 24                         0                    0      1
# 25                         0                    0      1
# 26                         0                    0      1
# 27                         0                    0      1
# 28                         0                    0      1
# 29                         0                    0      1
# ...                      ...                  ...    ...
# 1458                       1                    0      0
# 1459                       1                    0      0
# 1460                       1                    0      0
# 1461                       1                    0      0
# 1462                       1                    0      0
# 1463                       1                    0      0
# 1464                       1                    0      0
# 1465                       1                    0      0
# 1466                       1                    0      0
# 1467                       1                    0      0
# 1468                       1                    0      0
# 1469                       1                    0      0
# 1470                       0                    0      1
# 1471                       0                    0      1
# 1472                       0                    0      1
# 1473                       1                    0      0
# 1474                       1                    0      0
# 1475                       1                    0      0
# 1476                       1                    0      0
# 1477                       1                    0      0
# 1478                       1                    0      0
# 1479                       1                    0      0
# 1480                       1                    0      0
# 1481                       1                    0      0
# 1482                       1                    0      0
# 1483                       1                    0      0
# 1484                       1                    0      0
# 1485                       1                    0      0
# 1486                       1                    0      0
# 1487                       1                    0      0
#
# [1488 rows x 13 columns]

# %%
X = bike.drop(['cnt'], axis=1)
y = bike['cnt']
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1190 entries, 584 to 1192
# Data columns (total 12 columns):
# hr                        1190 non-null int64
# holiday                   1190 non-null int64
# workingday                1190 non-null int64
# temp                      1190 non-null float64
# hum                       1190 non-null float64
# windspeed                 1190 non-null float64
# instant                   1190 non-null int64
# mnth                      1190 non-null int64
# yr                        1190 non-null int64
# Clear to partly cloudy    1190 non-null int64
# Light Precipitation       1190 non-null int64
# Misty                     1190 non-null int64
# dtypes: float64(3), int64(9)
# memory usage: 120.9 KB

# %%
# Import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor

# Instantiate rf
rf = RandomForestRegressor(n_estimators=25,
            random_state=2)
            
# Fit rf to the training set    
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=25, n_jobs=None,
#            oob_score=False, random_state=2, verbose=0, warm_start=False)

# %%
# Import mean_squared_error as MSE
from sklearn.metrics import mean_squared_error as MSE

# Predict the test set labels
y_pred = rf.predict(X_test)

# Evaluate the test set RMSE
rmse_test = MSE(y_test, y_pred)**(1/2)

# Print rmse_test
print('Test set RMSE of rf: {:.2f}'.format(rmse_test))
# Out:
# Test set RMSE of rf: 54.49

# %%
# Create a pd.Series of features importances
importances = pd.Series(data=rf.feature_importances_,
                        index= X_train.columns)

# Sort importances
importances_sorted = importances.sort_values()

# Draw a horizontal barplot of importances_sorted
importances_sorted.plot(kind='barh', color='lightgreen')
plt.title('Features Importances')
plt.show()
